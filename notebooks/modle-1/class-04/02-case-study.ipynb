# %% [markdown]
# # Case Study

# %%
# imports
import pandas as pd
import numpy as np

# %% [markdown]
# Load Data

# %%
product_df = pd.read_csv("Products.csv")
shipping_df = pd.read_csv("Shipping.csv")
stores_df = pd.read_csv("Stores.csv")
transaction_df = pd.read_csv("Transactions.csv")

# %%
product_df.head(2)

# %% [markdown]
# Finding Null Values

# %%
product_df.isna()

# %%
shipping_df.isna()

# %%
stores_df.isna().sum()

# %%
transaction_df.isna()

# %% [markdown]
# Add Store IDs

# %%
store_ids = list(range(1,11))
for store_index in stores_df["StoreID"].index:
    stores_df.loc[store_index, "StoreID"] = store_ids[store_index]

stores_df.head(5)
